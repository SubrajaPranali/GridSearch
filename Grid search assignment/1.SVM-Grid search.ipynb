# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#reading the dataset
dataset =pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#convert the categorical data into nominal data
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Spliting the input and output
independent=dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid={'kernel':['linear','poly','rbf','sigmoid'],
            'C':[1,10,100]}
grid =GridSearchCV(SVR(), param_grid, refit = True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
#print the best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 100, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.133217      0.002380         0.022207        0.000669       1
# 1        0.121577      0.005622         0.024761        0.001244       1
# 2        0.149563      0.002742         0.059815        0.000926       1
# 3        0.176231      0.004146         0.036303        0.000743       1
# 4        0.140595      0.006214         0.021320        0.000602      10
# 5        0.125113      0.003028         0.022017        0.000001      10
# 6        0.149119      0.004622         0.061234        0.000380      10
# 7        0.176820      0.005178         0.036054        0.001145      10
# 8        0.269624      0.008790         0.021332        0.000858     100
# 9        0.134395      0.003486         0.021987        0.000488     100
# 10       0.145829      0.003255         0.059748        0.001221     100
# 11       0.159771      0.015395         0.023641        0.002338     100
#
#    param_kernel                           params  split0_test_score  \
# 0        linear     {'C': 1, 'kernel': 'linear'}          -0.147592
# 1          poly       {'C': 1, 'kernel': 'poly'}          -0.093867
# 2           rbf        {'C': 1, 'kernel': 'rbf'}          -0.115390
# 3       sigmoid    {'C': 1, 'kernel': 'sigmoid'}          -0.115186
# 4        linear    {'C': 10, 'kernel': 'linear'}          -0.018943
# 5          poly      {'C': 10, 'kernel': 'poly'}          -0.125153
# 6           rbf       {'C': 10, 'kernel': 'rbf'}          -0.110409
# 7       sigmoid   {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 8        linear   {'C': 100, 'kernel': 'linear'}           0.559313
# 9          poly     {'C': 100, 'kernel': 'poly'}          -0.132885
# 10          rbf      {'C': 100, 'kernel': 'rbf'}          -0.160182
# 11      sigmoid  {'C': 100, 'kernel': 'sigmoid'}          -0.142455
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.090685          -0.104805          -0.123874
# 1           -0.073490          -0.065017          -0.092734
# 2           -0.110235          -0.079858          -0.104068
# 3           -0.114434          -0.081691          -0.105744
# 4            0.029886           0.022167           0.003112
# 5           -0.081505          -0.111907          -0.131602
# 6           -0.097459          -0.074488          -0.099597
# 7           -0.119312          -0.085214          -0.108210
# 8            0.521798           0.547691           0.538805
# 9           -0.082461          -0.129220          -0.139962
# 10          -0.107253          -0.123430          -0.137753
# 11          -0.160831          -0.117544          -0.137984
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.202393        -0.133870        0.039226                9
# 1           -0.112204        -0.087462        0.016613                3
# 2           -0.108358        -0.103582        0.012406                5
# 3           -0.107748        -0.104961        0.012200                6
# 4           -0.066653        -0.006086        0.034672                2
# 5           -0.179328        -0.125899        0.031794                8
# 6           -0.124428        -0.101276        0.016459                4
# 7           -0.108716        -0.107639        0.012029                7
# 8            0.508518         0.535225        0.018122                1
# 9           -0.189219        -0.134749        0.033948               10
# 10          -0.209551        -0.147634        0.035511               12
# 11          -0.130402        -0.137843        0.014263               11

# %%
#checking
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 56
# Children: 67
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[30978.4789923]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
